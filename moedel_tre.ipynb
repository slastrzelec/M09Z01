# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\slast\PYTHON\AI\M09\Zad_1\df_ml_clean.csv", sep=";")

# %%
df.dtypes
df.tail(10)
# Out:
#       Płeć  5 km Tempo  Czas [s]
# 18401    K    5.350000   11716.0
# 18402    K    8.236667   11722.0
# 18403    M    6.893333   11769.0
# 18404    K    7.926667   11772.0
# 18405    K    7.986667   11866.0
# 18406    K    8.700000   11987.0
# 18407    K    8.420000   12068.0
# 18408    K    9.866667   12138.0
# 18409    K    9.360000   12512.0
# 18410    M   10.046667   12754.0

# %%
# Out:
# Pierwsze wiersze danych:
#   Płeć  5 km Tempo  Czas [s]
# 0    M    2.923333    3899.0
# 1    M    2.960000    3983.0
# 2    M    3.153333    4104.0
# 3    M    3.236667    4216.0
# 4    M    3.240000    4227.0
#
# Wymiary danych: (18411, 3)
#
# === WYNIKI MODELU ===
# R² Score: 0.8815
# RMSE: 420.77 sekund
# MAE: 305.77 sekund
#
# === PARAMETRY MODELU ===
# Współczynnik dla płci: 13.4229
# Współczynnik dla czasu 5km: 1379.4971
# Wyraz wolny: -303.8908
#
# === STATYSTYKI DLA KOBIET ===
# Liczba próbek: 1039
# R² Score: 0.8798
# RMSE: 401.67 sekund (6.69 minut)
# MAE: 304.12 sekund (5.07 minut)
#
# === STATYSTYKI DLA MĘŻCZYZN ===
# Liczba próbek: 2644
# R² Score: 0.8626
# RMSE: 428.04 sekund (7.13 minut)
# MAE: 306.42 sekund (5.11 minut)
# === PRZYKŁADOWA PREDYKCJA ===
# Aby przewidzieć czas dla nowego biegacza:
#
# Przykład 1: Mężczyzna, tempo na 5km = 5.0 min/km
# Przewidywany czas półmaratonu: 6607.02 sekund (110.12 minut)
#
# Przykład 2: Kobieta, tempo na 5km = 6.0 min/km
# ...
